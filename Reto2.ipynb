# %%
N= int(input("Ingrese el numero: "))
calculo= (((N**2)+2*N)/2)
print("El resultado de la operacion es: ",calculo)
# Out:
# El resultado de la operacion es:  12.0

# %%
Celsius= int(input("Ingrese la temperatura: "))
Fahrenheit= (Celsius*9/5)+32
print("La temperatura en Fahrenheit es: ",Fahrenheit,"°F")
# Out:
# La temperatura en Fahrenheit es:  86.0 °F

# %%
Texto= input("Ingrese un texto: ")
contar= len(Texto)
print("La cadena de texto tiene ",contar," caracteres.")
# Out:
# La cadena de texto tiene  7  caracteres.

# %%
Texto= input("Ingrese un texto: ")
print(Texto[3:])
# Out:
# i

# %%
Texto= input("Ingrese un texto: ")
print(Texto[2:-2])
# Out:
# la mun
