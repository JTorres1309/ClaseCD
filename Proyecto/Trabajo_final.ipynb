# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datos="https://raw.githubusercontent.com/JTorres1309/Proyecto_final_AD/a5287185a2a862e43d94b7753c80b24553be8ac3/Inventory%20Management%20E-Grocery%20-%20InventoryData.csv"
df=pd.read_csv(datos)
df.info(40)
print(df['SKU_Name'].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   SKU_ID                        1000 non-null   object
#  1   SKU_Name                      1000 non-null   object
#  2   Category                      1000 non-null   object
#  3   ABC_Class                     1000 non-null   object
#  4   Supplier_ID                   1000 non-null   object
#  5   Supplier_Name                 1000 non-null   object
#  6   Warehouse_ID                  1000 non-null   object
#  7   Warehouse_Location            1000 non-null   object
#  8   Batch_ID                      1000 non-null   object
#  9   Received_Date                 1000 non-null   object
#  10  Last_Purchase_Date            1000 non-null   object
#  11  Expiry_Date                   1000 non-null   object
# ...

# %%
df.head()
# Out:
#     SKU_ID              SKU_Name       Category ABC_Class Supplier_ID  \
# 0  SKU0001     Pantry Product 13         Pantry         A        S005
# 1  SKU0002     Fresh Product 112  Fresh Produce         C        S004
# 2  SKU0003      Meat Product 446           Meat         B        S001
# 3  SKU0004    Seafood Product 48        Seafood         A        S007
# 4  SKU0005  Personal Product 194  Personal Care         A        S002
#
#            Supplier_Name Warehouse_ID    Warehouse_Location   Batch_ID  \
# 0           PT Agro Raya        WHBDG   Bandung - Rancaekek  BATCH2679
# 1  PT Nusantara Supplier        WHDPS    Denpasar - Tabanan  BATCH4257
# 2        PT Segar Makmur        WHBDG   Bandung - Rancaekek  BATCH6574
# 3           PT Bakerindo        WHJKT  Jakarta - Cengkareng  BATCH5333
# 4          PT Indo Fresh        WHDPS    Denpasar - Tabanan  BATCH6925
#
#   Received_Date  ... SKU_Churn_Rate Order_Frequency_per_month  \
# ...

# %%
print(df['Supplier_Name'].unique())
media=df['Quantity_On_Hand'].mean()
print("El la cantidad promedio de productos en almacen es:", media)
print("El la cantidad maxima de productos en almacen es:", df['Quantity_On_Hand'].max(),"El producto es:",df.loc[df['Quantity_On_Hand'].idxmax()]['SKU_Name'])
print("El la cantidad minima de productos en almacen es:", df['Quantity_On_Hand'].min(), "El producto es:",df.loc[df['Quantity_On_Hand'].idxmin()]['SKU_Name'])
# Out:
# ['PT Agro Raya' 'PT Nusantara Supplier' 'PT Segar Makmur' 'PT Bakerindo'
#  'PT Indo Fresh' 'PT Beverage Nusantara' 'PT DailyDairy'
#  'PT Hygienic Supplies' 'PT Frozen Express' 'PT Prima Distribusi']
# El la cantidad promedio de productos en almacen es: 231.563
# El la cantidad maxima de productos en almacen es: 977 El producto es: Bakery Product 187
# El la cantidad minima de productos en almacen es: 0 El producto es: Household Product 48

# %%
df['Received_Date']=pd.to_datetime(df['Received_Date'])
print(df['Received_Date'])
df['Avg_Daily_Sales']=pd.to_numeric(df['Avg_Daily_Sales'], errors='coerce')
# Out:
# 0     2025-07-14
# 1     2025-04-08
# 2     2025-03-15
# 3     2025-06-10
# 4     2025-06-26
#          ...
# 995   2025-07-20
# 996   2025-03-16
# 997   2025-09-09
# 998   2025-05-07
# 999   2025-08-29
# Name: Received_Date, Length: 1000, dtype: datetime64[ns]

# %%
https://github.com/Twoeme/Prueba2/blob/main/Pandas_Class/clase_pandas_notebook.ipynb
# Out:
#   Cell In[37], line 1
#     https://github.com/Twoeme/Prueba2/blob/main/Pandas_Class/clase_pandas_notebook.ipynb
#           ^
# SyntaxError: invalid syntax

# %%
df.isna().sum()
# Out:
# SKU_ID                             0
# SKU_Name                           0
# Category                           0
# ABC_Class                          0
# Supplier_ID                        0
# Supplier_Name                      0
# Warehouse_ID                       0
# Warehouse_Location                 0
# Batch_ID                           0
# Received_Date                      0
# Last_Purchase_Date                 0
# Expiry_Date                        0
# Stock_Age_Days                     0
# Quantity_On_Hand                   0
# Quantity_Reserved                  0
# Quantity_Committed                 0
# Damaged_Qty                        0
# Returns_Qty                        0
# Avg_Daily_Sales                 1000
# Forecast_Next_30d                  0
# Days_of_Inventory                  0
# Reorder_Point                      0
# Safety_Stock                       0
# Lead_Time_Days                     0
# Unit_Cost_USD                      0
# ...

# %%
df.drop(columns=['Notes'], inplace=True)

# %%
# Ahora la base de datos no tiene na

# %%
df.isna().sum()
# Out:
# SKU_ID                             0
# SKU_Name                           0
# Category                           0
# ABC_Class                          0
# Supplier_ID                        0
# Supplier_Name                      0
# Warehouse_ID                       0
# Warehouse_Location                 0
# Batch_ID                           0
# Received_Date                      0
# Last_Purchase_Date                 0
# Expiry_Date                        0
# Stock_Age_Days                     0
# Quantity_On_Hand                   0
# Quantity_Reserved                  0
# Quantity_Committed                 0
# Damaged_Qty                        0
# Returns_Qty                        0
# Avg_Daily_Sales                 1000
# Forecast_Next_30d                  0
# Days_of_Inventory                  0
# Reorder_Point                      0
# Safety_Stock                       0
# Lead_Time_Days                     0
# Unit_Cost_USD                      0
# ...

# %%
#Lo creamos para cambiar el formato de las columnas de fecha
date_cols = df.filter(regex='_Date$').columns.tolist()
for c in date_cols:
    df[c] = pd.to_datetime(df[c], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   SKU_ID                        1000 non-null   object
#  1   SKU_Name                      1000 non-null   object
#  2   Category                      1000 non-null   object
#  3   ABC_Class                     1000 non-null   object
#  4   Supplier_ID                   1000 non-null   object
#  5   Supplier_Name                 1000 non-null   object
#  6   Warehouse_ID                  1000 non-null   object
#  7   Warehouse_Location            1000 non-null   object
#  8   Batch_ID                      1000 non-null   object
#  9   Received_Date                 1000 non-null   datetime64[ns]
#  10  Last_Purchase_Date            1000 non-null   object
#  11  Expiry_Date                   1000 non-null   object
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
 df.columns.tolist()
# Out:
# ['SKU_ID',
#  'SKU_Name',
#  'Category',
#  'ABC_Class',
#  'Supplier_ID',
#  'Supplier_Name',
#  'Warehouse_ID',
#  'Warehouse_Location',
#  'Batch_ID',
#  'Received_Date',
#  'Last_Purchase_Date',
#  'Expiry_Date',
#  'Stock_Age_Days',
#  'Quantity_On_Hand',
#  'Quantity_Reserved',
#  'Quantity_Committed',
#  'Damaged_Qty',
#  'Returns_Qty',
#  'Avg_Daily_Sales',
#  'Forecast_Next_30d',
#  'Days_of_Inventory',
#  'Reorder_Point',
#  'Safety_Stock',
#  'Lead_Time_Days',
#  'Unit_Cost_USD',
#  'Last_Purchase_Price_USD',
#  'Total_Inventory_Value_USD',
#  'SKU_Churn_Rate',
#  'Order_Frequency_per_month',
#  'Supplier_OnTime_Pct',
#  'FIFO_FEFO',
#  'Inventory_Status',
#  'Count_Variance',
#  'Audit_Date',
#  'Audit_Variance_Pct',
#  'Demand_Forecast_Accuracy_Pct',
#  'Notes']

# %%
def contar_por_clase(dataframe, columna='ABC_Class'):
    conteo = dataframe[columna].value_counts().sort_index()
    print(f"Conteo por {columna}:")
    print(conteo)
    return conteo
resultado = contar_por_clase(df)
# Out:
# Conteo por ABC_Class:
# ABC_Class
# A    200
# B    300
# C    500
# Name: count, dtype: int64

# %%
plt.xlabel("Category")
plt.ylabel("Average Daily Sales")
plt.title("Average Daily Sales by Category")
plt.bar(df['Category'], df['Average_Daily_Sales'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Juan David Torres R\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Average_Daily_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(df['Avg_Daily_Sales'])
# Out:
# 0      28,57
# 1      34,99
# 2      36,55
# 3      25,49
# 4      17,05
#        ...
# 995    31,90
# 996    40,03
# 997    26,13
# 998    23,48
# 999    11,88
# Name: Avg_Daily_Sales, Length: 1000, dtype: object
